# %%
from datetime import datetime as dt
from collections import defaultdict
import time
import numpy as np
import pandas as pd
import math
from scipy import stats
from scipy.signal import argrelextrema
from scipy.signal import savgol_filter
import statsmodels.api as sm
from sympy import *
import pytz
import itertools
import matplotlib.pyplot as plt
from itertools import combinations
from itertools import product
from itertools import groupby
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import MetaTrader5 as mt5

# %%
if not mt5.initialize(path="C:/MetaTrader_A/MetaTrader 5/terminal64.exe",login=1049732, server="TradersWay-Demo",password="r5AH8znU"):
    print("initialize() failed, error code =",mt5.last_error())
    quit()

# %%
def MetaLink(p,x,y,z):
    if x == "D1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_D1, z, y)
    elif x == "H8":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H8, z, y)
    elif x == "H4":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H4, z, y)
    elif x == "H3":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H3, z, y)
    elif x == "H2":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H2, z, y)
    elif x == "H1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H1, z, y)
    elif x == "M30":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M30, z, y)
    elif x == "M15":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M15, z, y)
    elif x == "M5":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M5, z, y)
    elif x == "M1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M1, z, y)
    return data

# %%
def MetaLink_range(p,x,y,z):
    if x == "D1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_D1, y, z)
    elif x == "H8":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H8, y, z)
    elif x == "H4":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H4, y, z)
    elif x == "H3":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H3, y, z)
    elif x == "H2":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H2, y, z)
    elif x == "H1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H1, y, z)
    elif x == "M30":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M30, y, z)
    elif x == "M15":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M15, y, z)
    elif x == "M5":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M5, y, z)
    elif x == "M1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M1, y, z)
    return data

# %%
def MetaLink_pos(p,x,y):
    if x == "D1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_D1, 0, y)
    elif x == "H8":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H8, 0, y)
    elif x == "H4":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H4, 0, y)
    elif x == "H3":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H3, 0, y)
    elif x == "H2":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H2, 0, y)
    elif x == "H1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H1, 0, y)
    elif x == "M30":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M30, 0, y)
    elif x == "M15":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M15, 0, y)
    elif x == "M5":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M5, 0, y)
    elif x == "M1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M1, 0, y)
    return data

# %%
def levelgrab(pair):
    
    levslist = []
    
    for x in pair:
        Srates = mt5.copy_rates_from_pos(x, mt5.TIMEFRAME_H1, 0, 1000)
        S = Srates
        SCM = np.average(abs(S['close'] - S['open']))
        y = S['close']
        LVL = np.concatenate((y[argrelextrema(y, np.greater)[0]],y[argrelextrema(y, np.less)[0]]))
        B = list(combinations(LVL, 2))
        Ba = np.array([x for x, y in B])
        B = np.array([abs(x - y) for x, y in B])
        Bb = np.array([np.where(x <= SCM, 1, 0) for x in B])
        T = [(Ba[i], Bb[i]) for i in range(0, len(Ba))] 
        Toutput = defaultdict(int) 
        for k, v in T: 
            Toutput[k] += v 
        table = list(Toutput.items())
        tablevs = [x for x, y in table]
        tabpings = [y for x, y in table]
        tabmax = argrelextrema(np.array(tabpings), np.greater)
        tabmax2 = list(tabmax[0])
        levs = np.array(tablevs)[tabmax2]
        levs = list(levs)
        levs.sort(reverse=True)
        levs = list(levs)
        
        mindist = min([abs(j-i) for i, j in zip(levs[:-1], levs[1:])])
        
        while mindist < SCM:
            i = 0
            h = -1
            j = 1
            for c in range(0, len(levs)):
                if j == len(levs):
                    j = -1
                if abs(levs[i]-levs[h]) < SCM:
                    levs[i] = 0
                elif abs(levs[i]-levs[j]) < SCM:
                    levs[i] = levs[i] - abs(levs[i]-levs[j])/2
                i += 1
                h += 1
                j += 1
            levs = [v for v in levs if v != 0]
            mindist = min([abs(a-b) for a, b in zip(levs[:-1], levs[1:])])
            
        levs = tuple(levs)

        levslist.append(levs)

    return levslist

# %%
def Pip_Screen(a,d):
    
    base, quote = a[:3], a[3:]

    if quote == "USD":
        exchange = 1.00
        if base == "XAG":
            D = d*10000
        elif base == "XAU":
            D = d*100
        elif base == "BTC":
            D = d*10
        elif base == "BCH":
            D = d*100
        elif base == "ETH":
            D = d*10
        elif base == "DSH":
            D = d*100
        elif base == "LTC":
            D = d*100
        elif base == "XMR":
            D = d*100
        elif base == "ZEC":
            D = d*100
        elif base == "ETC":
            D = d*1000
        elif base == "XRP":
            D = d*10000
        else:
            D = d*10000
    if quote == "USDt":
        exchange = 1.00
        if base == "BTC":
            D = d*10
    elif quote == "AUD":
        exchange = 1/(mt5.symbol_info("AUDUSD").bid)
        D = d*10000
    elif quote == "CAD":
        exchange = mt5.symbol_info("USDCAD").bid
        D = d*10000
    elif quote == "CHF":
        exchange = mt5.symbol_info("USDCHF").bid
        D = d*10000
    elif quote == "EUR":
        exchange = 1/(mt5.symbol_info("EURUSD").bid)
        D = d*10000
    elif quote == "GBP":
        exchange = 1/(mt5.symbol_info("GBPUSD").bid)
        D = d*10000
    elif quote == "JPY":
        exchange = mt5.symbol_info("USDJPY").bid
        D = d*100
    elif quote == "NZD":
        exchange = 1/(mt5.symbol_info("NZDUSD").bid)
        D = d*10000
    elif quote == 'NOK':
        exchange = mt5.symbol_info("USDNOK").bid
        D = d*1000
    elif quote == 'SEK':
        exchange = mt5.symbol_info("USDSEK").bid
        D = d*1000
    elif quote == 'SGD':
        exchange = mt5.symbol_info("USDSGD").bid
        D = d*10000
    elif quote == 'DKK':
        exchange = mt5.symbol_info("USDDKK").bid
        D = d*1000
    elif quote == 'MXN':
        exchange = mt5.symbol_info("USDMXN").bid
        D = d*1000
    elif quote == "entCrude":
        exchange = 1.00
        D = d*10
    elif quote == "ICrude":
        exchange = 1.00
        D = d*10
    elif quote == "TRY":
        exchange = mt5.symbol_info("USDTRY").bid
        D = d*10000
        
    return D

# %%
def Pip_ReverseScreen(a,d):
    
    base, quote = a[:3], a[3:]

    if quote == "USD":
        if base == "XAG":
            D = d/10000
        elif base == "XAU":
            D = d/100
        elif base == "BTC":
            D = d/10
        elif base == "BCH":
            D = d/100
        elif base == "ETH":
            D = d/10
        elif base == "DSH":
            D = d/100
        elif base == "LTC":
            D = d/100
        elif base == "XMR":
            D = d/100
        elif base == "ZEC":
            D = d/100
        elif base == "ETC":
            D = d/1000
        elif base == "XRP":
            D = d/10000
        else:
            D = d/10000
    if quote == "USDt":
        if base == "BTC":
            D = d/10
    elif quote == "AUD":
        D = d/10000
    elif quote == "CAD":
        D = d/10000
    elif quote == "CHF":
        D = d/10000
    elif quote == "EUR": 
        D = d/10000
    elif quote == "GBP":
        D = d/10000
    elif quote == "JPY":
        D = d/100
    elif quote == "NZD":
        D = d/10000
    elif quote == 'NOK':
        D = d/1000
    elif quote == 'SEK':
        D = d/1000
    elif quote == 'SGD':
        D = d/10000
    elif quote == 'DKK':
        D = d/1000
    elif quote == 'MXN':
        D = d/1000
    elif quote == "entCrude":
        exchange = 1.00
        D = d/10
    elif quote == "ICrude":
        exchange = 1.00
        D = d/10
    elif quote == "TRY":
        D = d/10000
        
    return D

# %%
def positioner(a,b,c,d,e):
    
    riskusd = 50.00        

    base, quote = a[:3], a[3:]
    
    ro = 2

    if quote == "USD":
        exchange = 1.00
        if base == "XAG":
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/1/stpips,ro)
        elif base == "XAU":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "BTC":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "BCH":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ETH":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "DSH":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "LTC":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "XMR":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ZEC":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ETC":
            stpips = abs(e - c)*1000
            lot = round(((riskusd*exchange)/10)/10/stpips,ro)
        elif base == "XRP":
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/1/stpips,ro)
        else:
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/stpips,ro)
    if quote == "USDt":
        exchange = 1.00
        if base == "BTC":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "AUD":
        exchange = 1/(mt5.symbol_info("AUDUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "CAD":
        exchange = mt5.symbol_info("USDCAD").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "CHF":
        exchange = mt5.symbol_info("USDCHF").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "EUR":
        exchange = 1/(mt5.symbol_info("EURUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "GBP":
        exchange = 1/(mt5.symbol_info("GBPUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "JPY":
        exchange = mt5.symbol_info("USDJPY").bid
        stpips = abs(e - c)*100
        lot = round(((riskusd*exchange)/10)/100/stpips,ro)
    elif quote == "NZD":
        exchange = 1/(mt5.symbol_info("NZDUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == 'NOK':
        exchange = mt5.symbol_info("USDNOK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'SEK':
        exchange = mt5.symbol_info("USDSEK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'SGD':
        exchange = mt5.symbol_info("USDSGD").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == 'DKK':
        exchange = mt5.symbol_info("USDDKK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'MXN':
        exchange = mt5.symbol_info("USDMXN").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == "entCrude":
        exchange = 1.00
        stpips = abs(e - c)*10
        lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "ICrude":
        exchange = 1.00
        stpips = abs(e - c)*10
        lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "TRY":
        exchange = mt5.symbol_info("USDTRY").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
        
    deviation = 20
    
    if b == "LONG":
        price = mt5.symbol_info_tick(a).ask
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": a,
            "volume": lot,
            "type": mt5.ORDER_TYPE_BUY,
            "price": price,
            "sl": e,
            "tp": d,
            "deviation": deviation,
            "magic": 234000,
            "comment": "BERMUDA",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        selected=mt5.symbol_select(a,True)
        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"
    elif b == "SHORT":
        price = mt5.symbol_info_tick(a).bid
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": a,
            "volume": lot,
            "type": mt5.ORDER_TYPE_SELL,
            "price": price,
            "sl": e,
            "tp": d,
            "deviation": deviation,
            "magic": 234000,
            "comment": "BERMUDA",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        selected=mt5.symbol_select(a,True)
        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"
            
    lotflag = "GREEN"
    if lot == 0:
        lotflag = "RED"
    
    return request, lotflag

# %%
def BERMUDA(pair, levslist):
    
    ia = 0
    for p in pair:
    
        D = MetaLink_pos(p,"M5",100)
        STy = Pip_Screen(p,D['close'])
        STx = range(0,len(STy))
        slope, intercept, r_value, p_value, std_err = stats.linregress(STx,STy)
        ST_slope = slope
        scopetheta = abs(math.degrees(math.atan(ST_slope)))
        if scopetheta > 40:

            S = savgol_filter(STy, 21, 3)
            tops = S[argrelextrema(S, np.greater)[0]]
            slope, intercept, r_value, p_value, std_err = stats.linregress(range(0,len(tops)),tops)
            tops_slope = slope

            bottoms = S[argrelextrema(S, np.less)[0]]
            slope, intercept, r_value, p_value, std_err = stats.linregress(range(0,len(bottoms)),bottoms)
            bottoms_slope = slope
            
            if ST_slope > 0:
                slope_variance = (bottoms_slope - tops_slope)/tops_slope
                if slope_variance > 0.30:
                    if D['close'][-1] < bottoms[-1]:
                        position = "LONG"
                    else:
                        position = 0
                else:
                    position = 0
            else:
                slope_variance = (tops_slope - bottoms_slope)/bottoms_slope
                if slope_variance > 0.30:
                    if D['close'][-1] > tops[-1]:
                        position = "SHORT"
                    else:
                        position = 0
                else:
                    position = 0     
            
            if position != 0:
                
                entry = D['close'][-1]
                levels = levslist[ia]
                lastone = abs(levels[0] - entry)
                q = 0
                for x in levels:
                    if q == 0:
                        Q = q
                    leveldiff = abs(x - entry)
                    if leveldiff < lastone:
                        Q = q
                    lastone = leveldiff
                    q += 1
                CTESTLVL = levels[Q]
                
                cend = int(len(levels)-1)
                if position == 'LONG':
                    clindex = levels.index(CTESTLVL)
                    tpindex = int(clindex - 1)
                    slindex = int(clindex + 1)
                    if clindex == 0:
                        stoploss = levels[slindex]
                        sldist = entry - stoploss
                        takeprofit = entry + sldist
                    elif clindex == cend:
                        takeprofit = levels[tpindex]
                        tpdist = takeprofit - entry
                        stoploss = entry - tpdist
                    else:
                        takeprofit = levels[tpindex]
                        stoploss = levels[slindex]
                elif position == 'SHORT':
                    clindex = levels.index(CTESTLVL)
                    tpindex = int(clindex + 1)
                    slindex = int(clindex - 1)
                    if clindex == 0:
                        takeprofit = levels[tpindex]
                        tpdist = entry - takeprofit
                        stoploss = entry + tpdist
                    elif clindex == cend:
                        stoploss = levels[slindex]
                        sldist = stoploss - entry
                        takeprofit = entry - sldist
                    else:
                        takeprofit = levels[tpindex]
                        stoploss = levels[slindex]
                else:
                    takeprofit = 0
                    stoploss = 0

                shrink = 0.90
                if position == 'LONG':
                    tpdist = takeprofit - entry
                    takeprofit = entry + tpdist*shrink
                elif position == 'SHORT':
                    tpdist = entry - takeprofit
                    takeprofit = entry - tpdist*shrink

                if position == 'LONG':
                    tpdist = takeprofit - entry
                    sldist = entry - stoploss
                    if sldist > tpdist:
                        stoploss = entry - tpdist
                elif position == 'SHORT':
                    tpdist = entry - takeprofit
                    sldist = stoploss - entry
                    if sldist > tpdist:
                        stoploss = entry + tpdist

                if position == 'LONG':
                    request, lotflag = positioner(p,"LONG",entry,takeprofit,stoploss)
                    if lotflag == "GREEN":
                        result = mt5.order_send(request)
                        if result.retcode != mt5.TRADE_RETCODE_DONE:
                            print("order_send failed, retcode={}".format(result.retcode))
                            result_dict=result._asdict()
                            for field in result_dict.keys():
                                print("   {}={}".format(field,result_dict[field]))
                                if field=="request":
                                    traderequest_dict=result_dict[field]._asdict()
                                    for tradereq_filed in traderequest_dict:
                                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
                        else:
                            print("Trade Placed:   ",p,"   ","Long","   TP:  ",takeprofit,"   SL:  ",stoploss,)
                elif position == 'SHORT':
                    request, lotflag = positioner(p,"SHORT",entry,takeprofit,stoploss)
                    if lotflag == "GREEN":
                        result = mt5.order_send(request)
                        if result.retcode != mt5.TRADE_RETCODE_DONE:
                            print("order_send failed, retcode={}".format(result.retcode))
                            result_dict=result._asdict()
                            for field in result_dict.keys():
                                print("   {}={}".format(field,result_dict[field]))
                                if field=="request":
                                    traderequest_dict=result_dict[field]._asdict()
                                    for tradereq_filed in traderequest_dict:
                                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
                        else:
                            print("Trade Placed:   ",p,"   ","Short","   TP:  ",takeprofit,"   SL:  ",stoploss,)
                print(p,position,entry,takeprofit,stoploss,lotflag)
        ia += 1

# %%
print("Initializing...")
pair = []
symbols=mt5.symbols_get()
for s in symbols:
    pair.append(s.name)
    
levslist = levelgrab(pair)
    
t2 = 0
while True:
    Drates = mt5.copy_rates_from_pos("EURUSD", mt5.TIMEFRAME_M5, 0, 1)
    D = Drates[0]
    t = D[0]
    if t2 != 0:
        if t != t2:
            print("Analyzing Markets...")
            BERMUDA(pair, levslist)
    t2 = t
    time.sleep(1)
# Out:
# Initializing...
# Analyzing Markets...
# order_send failed, retcode=10014
#    retcode=10014
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid volume
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XAGUSD', volume=0.01, price=24.257, stoplimit=0.0, sl=24.141275, tp=24.276725, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XAGUSD
#        traderequest: volume=0.01
#        traderequest: price=24.257
#        traderequest: stoplimit=0.0
#        traderequest: sl=24.141275
#        traderequest: tp=24.276725
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# XAGUSD LONG 24.209 24.276725 24.141275 GREEN
# XAUUSD LONG 1973.33 1974.9409999999998 1971.719 RED
# BCHUSD LONG 292.05 295.46325 288.63675 RED
# XMRUSD LONG 87.97 90.94 85.0 RED
# Analyzing Markets...
# order_send failed, retcode=10014
#    retcode=10014
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid volume
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XAGUSD', volume=0.01, price=24.262, stoplimit=0.0, sl=24.141275, tp=24.276725, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XAGUSD
#        traderequest: volume=0.01
#        traderequest: price=24.262
#        traderequest: stoplimit=0.0
#        traderequest: sl=24.141275
#        traderequest: tp=24.276725
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# XAGUSD LONG 24.209 24.276725 24.141275 GREEN
# XAUUSD LONG 1973.37 1975.0169999999998 1971.723 RED
# BCHUSD LONG 292.55 296.41325 288.68675 RED
# XMRUSD LONG 88.02 91.035 85.005 RED
# Analyzing Markets...
# XAUUSD LONG 1972.93 1974.181 1971.679 RED
# XMRUSD LONG 87.9 90.80700000000002 84.993 RED
# Analyzing Markets...
# XAUUSD LONG 1973.46 1975.188 1971.732 RED
# XMRUSD LONG 87.47 89.99 84.95 RED
# Analyzing Markets...
# XAUUSD LONG 1973.1 1974.504 1971.696 RED
# XMRUSD LONG 87.75 90.52199999999999 84.97800000000001 RED
# Analyzing Markets...
# XAUUSD LONG 1972.7 1973.9577499999998 1971.4422500000003 RED
# XMRUSD LONG 87.99 90.978 85.002 RED
# Analyzing Markets...
# XAUUSD LONG 1972.89 1974.1050000000002 1971.675 RED
# Analyzing Markets...
# Analyzing Markets...
# order_send failed, retcode=10014
#    retcode=10014
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid volume
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XAGUSD', volume=0.01, price=24.234, stoplimit=0.0, sl=24.095674999999996, tp=24.274325, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XAGUSD
#        traderequest: volume=0.01
#        traderequest: price=24.234
#        traderequest: stoplimit=0.0
#        traderequest: sl=24.095674999999996
#        traderequest: tp=24.274325
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# XAGUSD LONG 24.185 24.274325 24.095674999999996 GREEN
# XAUUSD LONG 1973.61 1975.473 1971.7469999999998 RED
# Analyzing Markets...
# Analyzing Markets...
# XAUUSD LONG 1973.88 1975.9860000000003 1971.774 RED
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# XAUUSD LONG 1974.09 1976.3849999999998 1971.795 RED
# Analyzing Markets...
# XAUUSD LONG 1974.2 1976.594 1971.806 RED
# XMRUSD LONG 88.39 91.738 85.042 RED
# Analyzing Markets...
# XAUUSD LONG 1973.51 1975.283 1971.737 RED
# XMRUSD LONG 88.56 92.061 85.059 RED
# Analyzing Markets...
# XMRUSD LONG 88.14 91.263 85.017 RED
# Analyzing Markets...
# XMRUSD LONG 88.36 91.681 85.039 RED
# Analyzing Markets...
# XMRUSD LONG 88.74 92.40299999999999 85.077 RED
# Analyzing Markets...
# XMRUSD LONG 88.62 92.17500000000001 85.065 RED
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# XAUUSD LONG 1975.85 1979.7289999999998 1971.971 RED
# Analyzing Markets...
# XAUUSD LONG 1975.51 1979.083 1971.937 RED
# Analyzing Markets...
# XAUUSD LONG 1975.12 1978.3419999999999 1971.898 RED
# Analyzing Markets...
# XAUUSD LONG 1974.91 1977.9430000000002 1971.877 RED
# Analyzing Markets...
# XAUUSD LONG 1976.01 1980.033 1971.987 RED
# Analyzing Markets...
# XAUUSD LONG 1976.54 1981.04 1972.04 RED
# Analyzing Markets...
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.59, price=8.2152, stoplimit=0.0, sl=8.19831225, tp=8.21018775, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.59
#        traderequest: price=8.2152
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.19831225
#        traderequest: tp=8.21018775
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20425 8.21018775 8.19831225 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.85, price=6.97503, stoplimit=0.0, sl=6.965904500000001, tp=6.969675499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.85
#        traderequest: price=6.97503
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.965904500000001
#        traderequest: tp=6.969675499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96779 6.969675499999999 6.965904500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.53, price=8.21367, stoplimit=0.0, sl=8.19690625, tp=8.21011375, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.53
#        traderequest: price=8.21367
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.19690625
#        traderequest: tp=8.21011375
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20351 8.21011375 8.19690625 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.91, price=6.9743, stoplimit=0.0, sl=6.9660375000000005, tp=6.969682499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.91
#        traderequest: price=6.9743
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9660375000000005
#        traderequest: tp=6.969682499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96786 6.969682499999999 6.9660375000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.66, price=8.21549, stoplimit=0.0, sl=8.19966125, tp=8.21025875, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.66
#        traderequest: price=8.21549
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.19966125
#        traderequest: tp=8.21025875
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20496 8.21025875 8.19966125 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.96, price=6.97439, stoplimit=0.0, sl=6.9661325, tp=6.9696875, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.96
#        traderequest: price=6.97439
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9661325
#        traderequest: tp=6.9696875
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96791 6.9696875 6.9661325 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.86, price=6.97433, stoplimit=0.0, sl=6.9659235000000015, tp=6.969676499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.86
#        traderequest: price=6.97433
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9659235000000015
#        traderequest: tp=6.969676499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.9678 6.969676499999999 6.9659235000000015 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.87, price=6.97434, stoplimit=0.0, sl=6.965942500000001, tp=6.9696774999999995, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.87
#        traderequest: price=6.97434
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.965942500000001
#        traderequest: tp=6.9696774999999995
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96781 6.9696774999999995 6.965942500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=2.02, price=6.97457, stoplimit=0.0, sl=6.9662465000000005, tp=6.9696935, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=2.02
#        traderequest: price=6.97457
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9662465000000005
#        traderequest: tp=6.9696935
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96797 6.9696935 6.9662465000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.85, price=6.97456, stoplimit=0.0, sl=6.965904500000001, tp=6.969675499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.85
#        traderequest: price=6.97456
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.965904500000001
#        traderequest: tp=6.969675499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96779 6.969675499999999 6.965904500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.98, price=6.97454, stoplimit=0.0, sl=6.9661705000000005, tp=6.969689499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.98
#        traderequest: price=6.97454
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9661705000000005
#        traderequest: tp=6.969689499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96793 6.969689499999999 6.9661705000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.44, price=8.22586, stoplimit=0.0, sl=8.20151, tp=8.245996, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.44
#        traderequest: price=8.22586
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245996
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20942 8.245996 8.20151 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.39, price=8.22651, stoplimit=0.0, sl=8.20151, tp=8.246106, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.39
#        traderequest: price=8.22651
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.246106
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.21052 8.246106 8.20151 GREEN
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.56, price=6.97385, stoplimit=0.0, sl=6.965182500000001, tp=6.969637499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.56
#        traderequest: price=6.97385
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.965182500000001
#        traderequest: tp=6.969637499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96741 6.969637499999999 6.965182500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=0.99, price=6.97439, stoplimit=0.0, sl=6.967642, tp=6.974698, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=0.99
#        traderequest: price=6.97439
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.967642
#        traderequest: tp=6.974698
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97117 6.974698 6.967642 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.0, price=6.97433, stoplimit=0.0, sl=6.967737, tp=6.974703, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.0
#        traderequest: price=6.97433
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.967737
#        traderequest: tp=6.974703
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97122 6.974703 6.967737 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=0.97, price=6.97434, stoplimit=0.0, sl=6.967471, tp=6.974689, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=0.97
#        traderequest: price=6.97434
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.967471
#        traderequest: tp=6.974689
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97108 6.974689 6.967471 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.0, price=6.97468, stoplimit=0.0, sl=6.967737, tp=6.974703, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.0
#        traderequest: price=6.97468
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.967737
#        traderequest: tp=6.974703
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97122 6.974703 6.967737 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.53, price=8.22112, stoplimit=0.0, sl=8.20151, tp=8.245865, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.53
#        traderequest: price=8.22112
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245865
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20811 8.245865 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=0.97, price=6.97483, stoplimit=0.0, sl=6.967528000000001, tp=6.974692, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=0.97
#        traderequest: price=6.97483
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.967528000000001
#        traderequest: tp=6.974692
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97111 6.974692 6.967528000000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.79, price=8.22226, stoplimit=0.0, sl=8.201504250000001, tp=8.21035575, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.79
#        traderequest: price=8.22226
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.201504250000001
#        traderequest: tp=8.21035575
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20593 8.21035575 8.201504250000001 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.8, price=6.97527, stoplimit=0.0, sl=6.96701, tp=6.974476, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.8
#        traderequest: price=6.97527
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.96701
#        traderequest: tp=6.974476
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.9689499999999995 6.974476 6.96701 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.7, price=8.2231, stoplimit=0.0, sl=8.20151, tp=8.245701, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.7
#        traderequest: price=8.2231
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245701
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20647 8.245701 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.85, price=6.97501, stoplimit=0.0, sl=6.96701, tp=6.97447, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.85
#        traderequest: price=6.97501
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.96701
#        traderequest: tp=6.97447
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96889 6.97447 6.96701 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.54, price=8.22333, stoplimit=0.0, sl=8.20151, tp=8.245847999999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.54
#        traderequest: price=8.22333
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245847999999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20794 8.245847999999999 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.64, price=6.97448, stoplimit=0.0, sl=6.96701, tp=6.974495, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.64
#        traderequest: price=6.97448
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.96701
#        traderequest: tp=6.974495
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96914 6.974495 6.96701 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.53, price=8.22353, stoplimit=0.0, sl=8.20151, tp=8.245858, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.53
#        traderequest: price=8.22353
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245858
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20804 8.245858 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=2.23, price=6.97379, stoplimit=0.0, sl=6.966588499999999, tp=6.9697115, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=2.23
#        traderequest: price=6.97379
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.966588499999999
#        traderequest: tp=6.9697115
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96815 6.9697115 6.966588499999999 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.73, price=8.2182, stoplimit=0.0, sl=8.20151, tp=8.245683, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.73
#        traderequest: price=8.2182
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245683
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20629 8.245683 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.95, price=6.9732199999999995, stoplimit=0.0, sl=6.9661135000000005, tp=6.9696865, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.95
#        traderequest: price=6.9732199999999995
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9661135000000005
#        traderequest: tp=6.9696865
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.9679 6.9696865 6.9661135000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.61, price=8.21977, stoplimit=0.0, sl=8.20151, tp=8.245771999999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.61
#        traderequest: price=8.21977
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245771999999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20718 8.245771999999999 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=2.04, price=6.97354, stoplimit=0.0, sl=6.966284500000001, tp=6.969695499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=2.04
#        traderequest: price=6.97354
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.966284500000001
#        traderequest: tp=6.969695499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96799 6.969695499999999 6.966284500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.61, price=8.21845, stoplimit=0.0, sl=8.20151, tp=8.245771999999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.61
#        traderequest: price=8.21845
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245771999999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20718 8.245771999999999 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=2.04, price=6.9734300000000005, stoplimit=0.0, sl=6.966284500000001, tp=6.969695499999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=2.04
#        traderequest: price=6.9734300000000005
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.966284500000001
#        traderequest: tp=6.969695499999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.96799 6.969695499999999 6.966284500000001 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.35, price=8.22473, stoplimit=0.0, sl=8.20151, tp=8.246213, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.35
#        traderequest: price=8.22473
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.246213
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.21159 8.246213 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.37, price=6.97591, stoplimit=0.0, sl=6.9697320000000005, tp=6.9748079999999995, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.37
#        traderequest: price=6.97591
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9697320000000005
#        traderequest: tp=6.9748079999999995
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97227 6.9748079999999995 6.9697320000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.27, price=8.22464, stoplimit=0.0, sl=8.20151, tp=8.246495, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.27
#        traderequest: price=8.22464
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.246495
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.21441 8.246495 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.19, price=6.97451, stoplimit=0.0, sl=6.969885, tp=6.977985, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.19
#        traderequest: price=6.97451
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.969885
#        traderequest: tp=6.977985
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97281 6.977985 6.969885 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.11, price=6.97454, stoplimit=0.0, sl=6.969885, tp=6.978006, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
# ...
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.43
#        traderequest: price=8.21442
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.246017
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20963 8.246017 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.2, price=6.97448, stoplimit=0.0, sl=6.969885, tp=6.977983, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.2
#        traderequest: price=6.97448
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.969885
#        traderequest: tp=6.977983
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97279 6.977983 6.969885 GREEN
# BTCUSD LONG 11264.7 11343.414 11185.986 RED
# BTCUSDt LONG 11264.7 11343.414 11185.986 RED
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.3, price=8.21587, stoplimit=0.0, sl=8.20151, tp=8.246372, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.3
#        traderequest: price=8.21587
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.246372
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.21318 8.246372 8.20151 GREEN
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=0.94, price=6.97476, stoplimit=0.0, sl=6.969885, tp=6.9780619999999995, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=0.94
#        traderequest: price=6.97476
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.969885
#        traderequest: tp=6.9780619999999995
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97358 6.9780619999999995 6.969885 GREEN
# XAGUSD LONG 24.348 24.4963875 24.199612499999997 RED
# BTCUSD LONG 11269.37 11352.287000000002 11186.453 RED
# BTCUSDt LONG 11269.37 11352.287000000002 11186.453 RED
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=0.9, price=6.97722, stoplimit=0.0, sl=6.97039, tp=6.97813, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=0.9
#        traderequest: price=6.97722
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.97039
#        traderequest: tp=6.97813
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97426 6.97813 6.97039 GREEN
# Analyzing Markets...
# Analyzing Markets...
# XAUUSD LONG 1975.33 1978.741 1971.9189999999999 RED
# BTCUSD LONG 11228.57 11274.767 11182.373 RED
# BTCUSDt LONG 11228.57 11274.767 11182.373 RED
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.34, price=6.97427, stoplimit=0.0, sl=6.9695990000000005, tp=6.974800999999999, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.34
#        traderequest: price=6.97427
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9695990000000005
#        traderequest: tp=6.974800999999999
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.9722 6.974800999999999 6.9695990000000005 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='USDTRY', volume=1.18, price=6.97421, stoplimit=0.0, sl=6.969885, tp=6.977988, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=USDTRY
#        traderequest: volume=1.18
#        traderequest: price=6.97421
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.969885
#        traderequest: tp=6.977988
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# USDTRY LONG 6.97284 6.977988 6.969885 GREEN
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.48, price=8.21979, stoplimit=0.0, sl=8.20151, tp=8.245935, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.48
#        traderequest: price=8.21979
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245935
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20881 8.245935 8.20151 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.45, price=8.21953, stoplimit=0.0, sl=8.20151, tp=8.245978, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.45
#        traderequest: price=8.21953
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.20151
#        traderequest: tp=8.245978
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20924 8.245978 8.20151 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.55, price=8.21684, stoplimit=0.0, sl=8.197476250000001, tp=8.21014375, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.55
#        traderequest: price=8.21684
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.197476250000001
#        traderequest: tp=8.21014375
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.20381 8.21014375 8.197476250000001 GREEN
# Analyzing Markets...
# Analyzing Markets...
# XAGUSD LONG 24.295 24.395687500000005 24.1943125 RED
# Analyzing Markets...
# order_send failed, retcode=10014
#    retcode=10014
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid volume
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XAGUSD', volume=0.01, price=24.328, stoplimit=0.0, sl=24.193912499999996, tp=24.388087500000005, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XAGUSD
#        traderequest: volume=0.01
#        traderequest: price=24.328
#        traderequest: stoplimit=0.0
#        traderequest: sl=24.193912499999996
#        traderequest: tp=24.388087500000005
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# XAGUSD LONG 24.291 24.388087500000005 24.193912499999996 GREEN
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.31, price=8.19938, stoplimit=0.0, sl=8.177665, tp=8.200255, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.31
#        traderequest: price=8.19938
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.177665
#        traderequest: tp=8.200255
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.18896 8.200255 8.177665 GREEN
# Analyzing Markets...
# order_send failed, retcode=10044
#    retcode=10044
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Only position closing is allowed
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='EURTRY', volume=0.33, price=8.20104, stoplimit=0.0, sl=8.179545999999998, tp=8.200354, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='BERMUDA', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=EURTRY
#        traderequest: volume=0.33
#        traderequest: price=8.20104
#        traderequest: stoplimit=0.0
#        traderequest: sl=8.179545999999998
#        traderequest: tp=8.200354
#        traderequest: deviation=20
#        traderequest: type=0
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BERMUDA
#        traderequest: position=0
#        traderequest: position_by=0
# EURTRY LONG 8.18995 8.200354 8.179545999999998 GREEN
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# XAGUSD LONG 24.33 24.4621875 24.197812499999998 RED
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# XAGUSD LONG 24.31 24.424187500000002 24.195812499999995 RED
# Analyzing Markets...
# XAGUSD LONG 24.332 24.465987500000004 24.198012499999997 RED
# Analyzing Markets...
# XAGUSD LONG 24.357 24.5134875 24.2005125 RED
# Analyzing Markets...
# XAGUSD LONG 24.314 24.431787500000002 24.196212499999998 RED
# Analyzing Markets...
# XAGUSD LONG 24.328 24.4583875 24.197612499999998 RED
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# XAUUSD LONG 1974.63 1977.4110000000003 1971.849 RED
# Analyzing Markets...
# XAUUSD LONG 1975.21 1978.5130000000001 1971.907 RED
# Analyzing Markets...
# XAUUSD LONG 1974.9 1977.9240000000002 1971.876 RED
# Analyzing Markets...
# Analyzing Markets...
# Analyzing Markets...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-81011e156382> in <module>
#      17             BERMUDA(pair, levslist)
#      18     t2 = t
# ---> 19     time.sleep(1)
#
# KeyboardInterrupt:
