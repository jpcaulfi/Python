# %%
from datetime import datetime as dt
from collections import defaultdict
import time
import numpy as np
import pandas as pd
import math
from scipy import stats
from scipy.signal import argrelextrema
from scipy.signal import savgol_filter
import statsmodels.api as sm
from sympy import *
import pytz
import itertools
import matplotlib.pyplot as plt
from itertools import combinations
from itertools import product
from itertools import groupby
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import MetaTrader5 as mt5

# %%
if not mt5.initialize(path="C:/MetaTrader_A/MetaTrader 5/terminal64.exe",login=1049732, server="TradersWay-Demo",password="r5AH8znU"):
    print("initialize() failed, error code =",mt5.last_error())
    quit()

# %%
def MetaLink(p,x,y,z):
    if x == "D1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_D1, z, y)
    elif x == "H8":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H8, z, y)
    elif x == "H4":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H4, z, y)
    elif x == "H3":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H3, z, y)
    elif x == "H2":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H2, z, y)
    elif x == "H1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_H1, z, y)
    elif x == "M30":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M30, z, y)
    elif x == "M15":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M15, z, y)
    elif x == "M5":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M5, z, y)
    elif x == "M1":
        data = mt5.copy_rates_from(p, mt5.TIMEFRAME_M1, z, y)
    return data

# %%
def MetaLink_range(p,x,y,z):
    if x == "D1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_D1, y, z)
    elif x == "H8":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H8, y, z)
    elif x == "H4":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H4, y, z)
    elif x == "H3":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H3, y, z)
    elif x == "H2":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H2, y, z)
    elif x == "H1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_H1, y, z)
    elif x == "M30":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M30, y, z)
    elif x == "M15":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M15, y, z)
    elif x == "M5":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M5, y, z)
    elif x == "M1":
        data = mt5.copy_rates_range(p, mt5.TIMEFRAME_M1, y, z)
    return data

# %%
def MetaLink_pos(p,x,y):
    if x == "D1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_D1, 0, y)
    elif x == "H8":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H8, 0, y)
    elif x == "H4":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H4, 0, y)
    elif x == "H3":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H3, 0, y)
    elif x == "H2":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H2, 0, y)
    elif x == "H1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_H1, 0, y)
    elif x == "M30":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M30, 0, y)
    elif x == "M15":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M15, 0, y)
    elif x == "M5":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M5, 0, y)
    elif x == "M1":
        data = mt5.copy_rates_from_pos(p, mt5.TIMEFRAME_M1, 0, y)
    return data

# %%
def Pip_Screen(a,d):
    
    base, quote = a[:3], a[3:]

    if quote == "USD":
        exchange = 1.00
        if base == "XAG":
            D = d*10000
        elif base == "XAU":
            D = d*100
        elif base == "BTC":
            D = d*10
        elif base == "BCH":
            D = d*100
        elif base == "ETH":
            D = d*10
        elif base == "DSH":
            D = d*100
        elif base == "LTC":
            D = d*100
        elif base == "XMR":
            D = d*100
        elif base == "ZEC":
            D = d*100
        elif base == "ETC":
            D = d*1000
        elif base == "XRP":
            D = d*10000
        else:
            D = d*10000
    if quote == "USDt":
        exchange = 1.00
        if base == "BTC":
            D = d*10
    elif quote == "AUD":
        exchange = 1/(mt5.symbol_info("AUDUSD").bid)
        D = d*10000
    elif quote == "CAD":
        exchange = mt5.symbol_info("USDCAD").bid
        D = d*10000
    elif quote == "CHF":
        exchange = mt5.symbol_info("USDCHF").bid
        D = d*10000
    elif quote == "EUR":
        exchange = 1/(mt5.symbol_info("EURUSD").bid)
        D = d*10000
    elif quote == "GBP":
        exchange = 1/(mt5.symbol_info("GBPUSD").bid)
        D = d*10000
    elif quote == "JPY":
        exchange = mt5.symbol_info("USDJPY").bid
        D = d*100
    elif quote == "NZD":
        exchange = 1/(mt5.symbol_info("NZDUSD").bid)
        D = d*10000
    elif quote == 'NOK':
        exchange = mt5.symbol_info("USDNOK").bid
        D = d*1000
    elif quote == 'SEK':
        exchange = mt5.symbol_info("USDSEK").bid
        D = d*1000
    elif quote == 'SGD':
        exchange = mt5.symbol_info("USDSGD").bid
        D = d*10000
    elif quote == 'DKK':
        exchange = mt5.symbol_info("USDDKK").bid
        D = d*1000
    elif quote == 'MXN':
        exchange = mt5.symbol_info("USDMXN").bid
        D = d*1000
    elif quote == "entCrude":
        exchange = 1.00
        D = d*10
    elif quote == "ICrude":
        exchange = 1.00
        D = d*10
    elif quote == "TRY":
        exchange = mt5.symbol_info("USDTRY").bid
        D = d*10000
        
    return D

# %%
def Pip_ReverseScreen(a,d):
    
    base, quote = a[:3], a[3:]

    if quote == "USD":
        if base == "XAG":
            D = d/10000
        elif base == "XAU":
            D = d/100
        elif base == "BTC":
            D = d/10
        elif base == "BCH":
            D = d/100
        elif base == "ETH":
            D = d/10
        elif base == "DSH":
            D = d/100
        elif base == "LTC":
            D = d/100
        elif base == "XMR":
            D = d/100
        elif base == "ZEC":
            D = d/100
        elif base == "ETC":
            D = d/1000
        elif base == "XRP":
            D = d/10000
        else:
            D = d/10000
    if quote == "USDt":
        if base == "BTC":
            D = d/10
    elif quote == "AUD":
        D = d/10000
    elif quote == "CAD":
        D = d/10000
    elif quote == "CHF":
        D = d/10000
    elif quote == "EUR": 
        D = d/10000
    elif quote == "GBP":
        D = d/10000
    elif quote == "JPY":
        D = d/100
    elif quote == "NZD":
        D = d/10000
    elif quote == 'NOK':
        D = d/1000
    elif quote == 'SEK':
        D = d/1000
    elif quote == 'SGD':
        D = d/10000
    elif quote == 'DKK':
        D = d/1000
    elif quote == 'MXN':
        D = d/1000
    elif quote == "entCrude":
        exchange = 1.00
        D = d/10
    elif quote == "ICrude":
        exchange = 1.00
        D = d/10
    elif quote == "TRY":
        D = d/10000
        
    return D

# %%
def levelgrab(pair):
    
    levslist = []
    
    for p in pair:
        
        S = MetaLink_pos(p,"H1",1000)
        SCM = np.average(abs(S['close'] - S['open']))
        y = savgol_filter(S['close'], 21, 3)
        LVL = np.concatenate((y[argrelextrema(y, np.greater)[0]],y[argrelextrema(y, np.less)[0]]))
        B = list(combinations(LVL, 2))
        Ba = np.array([x for x, y in B])
        B = np.array([abs(x - y) for x, y in B])
        Bb = np.array([np.where(x <= SCM, 1, 0) for x in B])
        T = [(Ba[i], Bb[i]) for i in range(0, len(Ba))] 
        Toutput = defaultdict(int) 
        for k, v in T: 
            Toutput[k] += v 
        table = list(Toutput.items())
        tablevs = [x for x, y in table]
        tabpings = [y for x, y in table]
        tabmax = argrelextrema(np.array(tabpings), np.greater)
        tabmax2 = list(tabmax[0])
        levs = np.array(tablevs)[tabmax2]
        levs = list(levs)
        levs.sort(reverse=True)           
        levs = tuple(levs)
        levslist.append(levs)

    return levslist, SCM

# %%
def levelwheel(levs, SCM):
    
    mindist = min([abs(j-i) for i, j in zip(levs[:-1], levs[1:])])
        
    while mindist < SCM:
        i = 0
        h = -1
        j = 1
        for c in range(0, len(levs)):
            if j == len(levs):
                j = -1
            if abs(levs[i]-levs[h]) < SCM:
                levs[i] = 0
            elif abs(levs[i]-levs[j]) < SCM:
                levs[i] = levs[i] - abs(levs[i]-levs[j])/2
            i += 1
            h += 1
            j += 1
        levs = [v for v in levs if v != 0]
        mindist = min([abs(a-b) for a, b in zip(levs[:-1], levs[1:])])

    levs = tuple(levs)

    return levs

# %%
def Trade_Check(current_trade):
    
    trade_flag = 1
    list_check = 1
    
    to_date=dt.now()
    delta1=timedelta(
        days=0,
        seconds=0,
        microseconds=0,
        milliseconds=0,
        minutes=0,
        hours=1,
        weeks=0
    )
    
    try:
        deals = mt5.history_orders_get(from_date, to_date)
        df = pd.DataFrame(list(deals),columns=deals[0]._asdict().keys())
        df['time_done'] = pd.to_datetime(df['time_done'], unit='s')
        df = df.drop(columns=['ticket', 'magic', 'position_by_id', 'reason', 'time_setup', 'time_setup_msc', 'time_done_msc', 'time_expiration', 'type_time', 'type_filling', 'external_id'])
        aggregation_functions = {'time_done': 'first', 'type': 'first', 'state': 'count', 'volume_initial': 'first', 'volume_current': 'first', 'price_open': 'first', 'sl': 'first', 'tp': 'first', 'price_current': 'first', 'price_stoplimit': 'last', 'symbol': 'first', 'comment': 'first'}
        df = df.groupby(df['position_id']).aggregate(aggregation_functions)
        block = pd.DataFrame(df, columns=['comment', 'state', 'symbol', 'type', 'time_done', 'price_current', 'tp', 'sl'])
        block = block.sort_values(by=['comment', 'time_done'])
        testa = pd.DataFrame(block[(block.comment == "BRUTUS gauge") & (block.state == 2)])
        testa = testa.drop(columns=['comment','state'])
        testa['type'] = np.where(testa['type'] == 1, "SHORT","LONG")
        testa.columns = ['symbol', 'type', 'time', 'entry', 'tp', 'sl']
        testa = testa.set_index('time')
        testa = testa.tz_localize('Etc/GMT-7')
        testa = testa.tz_convert('UTC')
        trade_symb = list(testa['symbol'])
        trade_type = list(testa['type'])
        trades = list(zip(trade_symb,trade_type))

    except ValueError:
        list_check = 0
    
    if list_check == 1:
        for t in trades:
            if t == current_trade:
                trade_flag = 0
        
    return trade_flag

# %%
def positioner(a,b,c,d,e):
    
    riskusd = 50.00        

    base, quote = a[:3], a[3:]
    
    ro = 2

    if quote == "USD":
        exchange = 1.00
        if base == "XAG":
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/1/stpips,ro)
        elif base == "XAU":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "BTC":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "BCH":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ETH":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "DSH":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "LTC":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "XMR":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ZEC":
            stpips = abs(e - c)*100
            lot = round(((riskusd*exchange)/10)/100/stpips,ro)
        elif base == "ETC":
            stpips = abs(e - c)*1000
            lot = round(((riskusd*exchange)/10)/10/stpips,ro)
        elif base == "XRP":
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/1/stpips,ro)
        else:
            stpips = abs(e - c)*10000
            lot = round(((riskusd*exchange)/10)/stpips,ro)
    if quote == "USDt":
        exchange = 1.00
        if base == "BTC":
            stpips = abs(e - c)*10
            lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "AUD":
        exchange = 1/(mt5.symbol_info("AUDUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "CAD":
        exchange = mt5.symbol_info("USDCAD").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "CHF":
        exchange = mt5.symbol_info("USDCHF").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "EUR":
        exchange = 1/(mt5.symbol_info("EURUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "GBP":
        exchange = 1/(mt5.symbol_info("GBPUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == "JPY":
        exchange = mt5.symbol_info("USDJPY").bid
        stpips = abs(e - c)*100
        lot = round(((riskusd*exchange)/10)/100/stpips,ro)
    elif quote == "NZD":
        exchange = 1/(mt5.symbol_info("NZDUSD").bid)
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == 'NOK':
        exchange = mt5.symbol_info("USDNOK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'SEK':
        exchange = mt5.symbol_info("USDSEK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'SGD':
        exchange = mt5.symbol_info("USDSGD").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
    elif quote == 'DKK':
        exchange = mt5.symbol_info("USDDKK").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == 'MXN':
        exchange = mt5.symbol_info("USDMXN").bid
        stpips = abs(e - c)*1000
        lot = round(((riskusd*exchange)/10)/10/stpips,ro)
    elif quote == "entCrude":
        exchange = 1.00
        stpips = abs(e - c)*10
        lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "ICrude":
        exchange = 1.00
        stpips = abs(e - c)*10
        lot = round(((riskusd*exchange)/10)/1000/stpips,ro)
    elif quote == "TRY":
        exchange = mt5.symbol_info("USDTRY").bid
        stpips = abs(e - c)*10000
        lot = round(((riskusd*exchange)/10)/stpips,ro)
        
    deviation = 20
    
    if b == "LONG":
        price = mt5.symbol_info_tick(a).ask
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": a,
            "volume": lot,
            "type": mt5.ORDER_TYPE_BUY,
            "price": price,
            "sl": e,
            "tp": d,
            "deviation": deviation,
            "magic": 234000,
            "comment": "BRUTUS v3 inverted",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        selected=mt5.symbol_select(a,True)
        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"
    elif b == "SHORT":
        price = mt5.symbol_info_tick(a).bid
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": a,
            "volume": lot,
            "type": mt5.ORDER_TYPE_SELL,
            "price": price,
            "sl": e,
            "tp": d,
            "deviation": deviation,
            "magic": 234000,
            "comment": "BRUTUS v3 inverted",
            "type_time": mt5.ORDER_TIME_GTC,
            "type_filling": mt5.ORDER_FILLING_IOC,
        }
        selected=mt5.symbol_select(a,True)
        if not selected:
            print("Failed to select pair")
            mt5.shutdown()
            quit()
            spy = "NO"
            
    lotflag = "GREEN"
    if lot == 0:
        lotflag = "RED"
    
    return request, lotflag

# %%
def brutus(pair,levslist,SCM):

    ia = 0
    for p in pair:         
        A = MetaLink_pos(p,"M5",80)
        P = Pip_Screen(p,A['close'])
        S = savgol_filter(A['close'], 13, 3)
        slope, intercept, r_value, p_value, std_err = stats.linregress(range(len(P)),P)
        ST = slope
        ST_theta = abs(math.degrees(math.atan(ST)))
        if ST_theta > 20:
            if ST > 0:
                try:
                    B = list(S)
                    break_peak = max(B)
                    bp_index = B.index(break_peak) 
                    B2 = B[:bp_index]
                    break_spawn = min(B2)
                    bs_index = B.index(break_spawn)
                    levels = list(levslist[ia])
                    Q = list(break_peak - levels)
                    Qi = [i for i in Q if i > 0]
                    Qi_min = min(Qi)
                    Qi_index = Q.index(Qi_min)
                    LVL = levels[Qi_index]
                    CM_avg = np.average(abs(A['close']-A['open']))
                    CM_std = np.std(abs(A['close']-A['open']))
                    if break_peak > LVL + CM_avg + CM_std:
                        if break_spawn < LVL - CM_avg - CM_std:
                            break_check = 1
                        else:
                            break_check = 0
                    else:
                        break_check = 0
                except ValueError:
                    break_check = 0
                if break_check == 1:
                    gap = break_peak - LVL
                    retrace = break_peak - A['close'][-2]
                    if retrace/gap >= 0.60:
                        retrace_check = 1
                    else:
                        retrace_check = 0
                else:
                    retrace_check = 0
                if retrace_check == 1:
                    C = S[-7:]
                    C1 = []
                    x = 0
                    for c in C:
                        if x == 0:
                            C1.append(0)
                        else:
                            cc = C[x] - C[x-1]
                            C1.append(cc)
                        x += 1
                    C2 = []
                    x = 0
                    for c in C1:
                        if x == 0:
                            C2.append(0)
                        else:
                            ccc = C1[x] - C1[x-1]
                            C2.append(ccc)
                        x += 1
                    if C2[-1] > 0:
                        print("Delta2Y #1 :  1")
                        if C2[-2] > 0:
                            print("Delta2Y #2 :  1")
                            if C2[-3] > 0:
                                print("Delta2Y #3 :  1")
                                delta_check = 1
                            else:
                                delta_check = 0
                        else:
                            delta_check = 0
                    else:
                        delta_check = 0
                else:
                    delta_check = 0
                if delta_check == 1:
                    entry = A['close'][-2]
                    takeprofit = entry + gap*1.5
                    stoploss = entry - (takeprofit - entry)/2
                    request, lotflag = positioner(p,"SHORT",entry,stoploss,takeprofit)
                    print(p,"SHORT",lotflag)
                    if lotflag == "GREEN":
                        result = mt5.order_send(request)
                        if result.retcode != mt5.TRADE_RETCODE_DONE:
                            print("order_send failed, retcode={}".format(result.retcode))
                            result_dict=result._asdict()
                            for field in result_dict.keys():
                                print("   {}={}".format(field,result_dict[field]))
                                if field=="request":
                                    traderequest_dict=result_dict[field]._asdict()
                                    for tradereq_filed in traderequest_dict:
                                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
                        else:
                            print("Trade Placed:   ",p,"   ","Short","   TP:  ",takeprofit,"   SL:  ",stoploss,)
            elif ST > 0:
                try:
                    B = list(S)
                    break_peak = min(B)
                    bp_index = B.index(break_peak) 
                    B2 = B[:bp_index]
                    break_spawn = max(B2)
                    bs_index = B.index(break_spawn)
                    levels = list(levslist[ia])
                    Q = list(break_peak - levels)
                    Qi = [i for i in Q if i < 0]
                    Qi_min = max(Qi)
                    Qi_index = Q.index(Qi_min)
                    LVL = levels[Qi_index]
                    CM_avg = np.average(abs(A['close']-A['open']))
                    CM_std = np.std(abs(A['close']-A['open']))
                    if break_peak < LVL - CM_avg - CM_std:
                        if break_spawn > LVL + CM_avg + CM_std:
                            break_check = 1
                        else:
                            break_check = 0
                    else:
                        break_check = 0
                except ValueError:
                    break_check = 0
                if break_check == 1:
                    gap = LVL - break_peak
                    retrace = A['close'][-2] - break_peak
                    if retrace/gap >= 0.60:
                        retrace_check = 1
                    else:
                        retrace_check = 0
                else:
                    retrace_check = 0
                if retrace_check == 1:
                    C = S[-7:]
                    C1 = []
                    x = 0
                    for c in C:
                        if x == 0:
                            C1.append(0)
                        else:
                            cc = C[x] - C[x-1]
                            C1.append(cc)
                        x += 1
                    C2 = []
                    x = 0
                    for c in C1:
                        if x == 0:
                            C2.append(0)
                        else:
                            ccc = C1[x] - C1[x-1]
                            C2.append(ccc)
                        x += 1
                    if C2[-1] < 0:
                        print("Delta2Y #1 :  1")
                        if C2[-2] < 0:
                            print("Delta2Y #2 :  1")
                            if C2[-3] < 0:
                                print("Delta2Y #3 :  1")
                                delta_check = 1
                            else:
                                delta_check = 0
                        else:
                            delta_check = 0
                    else:
                        delta_check = 0
                else:
                    delta_check = 0
                if delta_check == 1:
                    entry = A['close'][-2]
                    takeprofit = entry - gap*1.5
                    stoploss = entry + (entry - takeprofit)/2
                    request, lotflag = positioner(p,"LONG",entry,stoploss,takeprofit)
                    print(p,"LONG",lotflag)
                    if lotflag == "GREEN":
                        result = mt5.order_send(request)
                        if result.retcode != mt5.TRADE_RETCODE_DONE:
                            print("order_send failed, retcode={}".format(result.retcode))
                            result_dict=result._asdict()
                            for field in result_dict.keys():
                                print("   {}={}".format(field,result_dict[field]))
                                if field=="request":
                                    traderequest_dict=result_dict[field]._asdict()
                                    for tradereq_filed in traderequest_dict:
                                        print("       traderequest: {}={}".format(tradereq_filed,traderequest_dict[tradereq_filed]))
                        else:
                            print("Trade Placed:   ",p,"   ","Long","   TP:  ",takeprofit,"   SL:  ",stoploss,)
        ia += 1

# %%
print("Initializing...")

pair = []
symbols=mt5.symbols_get()
for s in symbols:
    pair.append(s.name)

levslist, SCM = levelgrab(pair)

t2 = 0
while True:
    Drates = MetaLink_pos("EURUSD","M5",1)
    D = Drates[0]
    t = D[0]
    if t2 != 0:
        if t != t2:
            print("Analyzing Markets...")
            brutus(pair,levslist,SCM)
            print("...Analysis Complete")
    t2 = t
    time.sleep(10)
# Out:
# Initializing...
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.073, stoplimit=0.0, sl=7.092691392132022, tp=7.037654303933989, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.073
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.092691392132022
#        traderequest: tp=7.037654303933989
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.25, price=0.3043, stoplimit=0.0, sl=0.3058622579651529, tp=0.30291887101742354, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.25
#        traderequest: price=0.3043
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3058622579651529
#        traderequest: tp=0.30291887101742354
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.12, price=0.3063, stoplimit=0.0, sl=0.30804632389921915, tp=0.30182683805039046, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.12
#        traderequest: price=0.3063
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30804632389921915
#        traderequest: tp=0.30182683805039046
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.05, stoplimit=0.0, sl=7.088831252271881, tp=7.030584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.05
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.088831252271881
#        traderequest: tp=7.030584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.043, stoplimit=0.0, sl=7.08283125227188, tp=7.024584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.043
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.08283125227188
#        traderequest: tp=7.024584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30633769502808955    SL:   0.30313115248595524
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.015, stoplimit=0.0, sl=7.08283125227188, tp=7.024584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.015
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.08283125227188
#        traderequest: tp=7.024584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3057376950280895    SL:   0.3025311524859552
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.032, stoplimit=0.0, sl=7.0778312522718805, tp=7.01958437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.032
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.0778312522718805
#        traderequest: tp=7.01958437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3036, stoplimit=0.0, sl=0.3046376950280895, tp=0.3014311524859552, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3036
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3046376950280895
#        traderequest: tp=0.3014311524859552
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.042, stoplimit=0.0, sl=7.0778312522718805, tp=7.01958437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.042
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.0778312522718805
#        traderequest: tp=7.01958437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3039, stoplimit=0.0, sl=0.3057376950280895, tp=0.3025311524859552, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3039
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3057376950280895
#        traderequest: tp=0.3025311524859552
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.053, stoplimit=0.0, sl=7.080831252271881, tp=7.02258437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.053
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.080831252271881
#        traderequest: tp=7.02258437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3043, stoplimit=0.0, sl=0.30603769502808953, tp=0.30283115248595527, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3043
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30603769502808953
#        traderequest: tp=0.30283115248595527
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.054, stoplimit=0.0, sl=7.091831252271881, tp=7.033584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.054
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.091831252271881
#        traderequest: tp=7.033584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.048, stoplimit=0.0, sl=7.092831252271881, tp=7.03458437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.048
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.092831252271881
#        traderequest: tp=7.03458437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3046376950280895    SL:   0.3014311524859552
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.011, stoplimit=0.0, sl=7.047831252271881, tp=6.98958437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.011
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.047831252271881
#        traderequest: tp=6.98958437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3021, stoplimit=0.0, sl=0.30393769502808954, tp=0.3007311524859553, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3021
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30393769502808954
#        traderequest: tp=0.3007311524859553
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.014, stoplimit=0.0, sl=7.049831252271881, tp=6.991584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.014
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.049831252271881
#        traderequest: tp=6.991584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3042376950280895    SL:   0.30103115248595524
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=7.013, stoplimit=0.0, sl=7.051831252271881, tp=6.99358437386406, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=7.013
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.051831252271881
#        traderequest: tp=6.99358437386406
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3040376950280895    SL:   0.30083115248595527
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30383769502808955    SL:   0.3006311524859553
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3011, stoplimit=0.0, sl=0.30293769502808954, tp=0.2997311524859553, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3011
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30293769502808954
#        traderequest: tp=0.2997311524859553
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=6.954, stoplimit=0.0, sl=6.9768312522718805, tp=6.918584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=6.954
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.9768312522718805
#        traderequest: tp=6.918584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3007, stoplimit=0.0, sl=0.3016376950280895, tp=0.2984311524859552, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3007
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3016376950280895
#        traderequest: tp=0.2984311524859552
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=6.963, stoplimit=0.0, sl=6.998831252271881, tp=6.940584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=6.963
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.998831252271881
#        traderequest: tp=6.940584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3018, stoplimit=0.0, sl=0.30283769502808955, tp=0.2996311524859553, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3018
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30283769502808955
#        traderequest: tp=0.2996311524859553
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=6.969, stoplimit=0.0, sl=6.998831252271881, tp=6.940584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=6.969
#        traderequest: stoplimit=0.0
#        traderequest: sl=6.998831252271881
#        traderequest: tp=6.940584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30393769502808954    SL:   0.3007311524859553
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=6.983, stoplimit=0.0, sl=7.007831252271881, tp=6.9495843738640595, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=6.983
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.007831252271881
#        traderequest: tp=6.9495843738640595
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.303, stoplimit=0.0, sl=0.30393769502808954, tp=0.3007311524859553, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.303
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30393769502808954
#        traderequest: tp=0.3007311524859553
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# ETCUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='ETCUSD', volume=0.01, price=6.98, stoplimit=0.0, sl=7.02183125227188, tp=6.963584373864059, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=ETCUSD
#        traderequest: volume=0.01
#        traderequest: price=6.98
#        traderequest: stoplimit=0.0
#        traderequest: sl=7.02183125227188
#        traderequest: tp=6.963584373864059
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3051376950280895    SL:   0.30193115248595526
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3018, stoplimit=0.0, sl=0.3027376950280895, tp=0.2995311524859552, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3018
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3027376950280895
#        traderequest: tp=0.2995311524859552
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# LTCUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3022, stoplimit=0.0, sl=0.30393769502808954, tp=0.3007311524859553, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3022
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30393769502808954
#        traderequest: tp=0.3007311524859553
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# BTCUSDt SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30433769502808955    SL:   0.30113115248595523
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6064945003166278    SL:   0.6054377498416862
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30333769502808955    SL:   0.30013115248595523
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6065245003166277    SL:   0.6054677498416862
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3032376950280895    SL:   0.30003115248595524
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3032376950280895    SL:   0.30003115248595524
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3015, stoplimit=0.0, sl=0.30333769502808955, tp=0.30013115248595523, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3015
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30333769502808955
#        traderequest: tp=0.30013115248595523
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.30333769502808955    SL:   0.30013115248595523
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6064145003166277    SL:   0.6053577498416861
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3015, stoplimit=0.0, sl=0.30333769502808955, tp=0.30013115248595523, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3015
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.30333769502808955
#        traderequest: tp=0.30013115248595523
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6065045003166278    SL:   0.6054477498416861
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6065645003166278    SL:   0.6055077498416861
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6063245003166278    SL:   0.6052677498416862
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDCHF SHORT GREEN
# Trade Placed:    NZDCHF     Short    TP:   0.6064645003166278    SL:   0.6054077498416861
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# order_send failed, retcode=10016
#    retcode=10016
#    deal=0
#    order=0
#    volume=0.0
#    price=0.0
#    bid=0.0
#    ask=0.0
#    comment=Invalid stops
#    request_id=0
#    retcode_external=0
#    request=TradeRequest(action=1, magic=234000, order=0, symbol='XRPUSD', volume=0.23, price=0.3, stoplimit=0.0, sl=0.3020376950280895, tp=0.29883115248595526, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='BRUTUS v3 inverted', position=0, position_by=0)
#        traderequest: action=1
#        traderequest: magic=234000
#        traderequest: order=0
#        traderequest: symbol=XRPUSD
#        traderequest: volume=0.23
#        traderequest: price=0.3
#        traderequest: stoplimit=0.0
#        traderequest: sl=0.3020376950280895
#        traderequest: tp=0.29883115248595526
#        traderequest: deviation=20
#        traderequest: type=1
#        traderequest: type_filling=1
#        traderequest: type_time=0
#        traderequest: expiration=0
#        traderequest: comment=BRUTUS v3 inverted
#        traderequest: position=0
#        traderequest: position_by=0
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# AUDJPY SHORT GREEN
# Trade Placed:    AUDJPY     Short    TP:   76.40242950070659    SL:   75.87528524964671
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XRPUSD SHORT GREEN
# Trade Placed:    XRPUSD     Short    TP:   0.3020376950280895    SL:   0.29883115248595526
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# AUDJPY SHORT GREEN
# Trade Placed:    AUDJPY     Short    TP:   76.4094295007066    SL:   75.88228524964671
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# AUDJPY SHORT GREEN
# Trade Placed:    AUDJPY     Short    TP:   76.3884295007066    SL:   75.86128524964671
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDUSD SHORT GREEN
# Trade Placed:    NZDUSD     Short    TP:   0.6637507643157876    SL:   0.6590996178421061
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# AUDJPY SHORT GREEN
# Trade Placed:    AUDJPY     Short    TP:   76.36742950070659    SL:   75.84028524964671
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDUSD SHORT GREEN
# Trade Placed:    NZDUSD     Short    TP:   0.6634907643157877    SL:   0.6588396178421062
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDUSD SHORT GREEN
# Trade Placed:    NZDUSD     Short    TP:   0.6635707643157877    SL:   0.6589196178421062
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# XMRUSD SHORT RED
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# NZDUSD SHORT GREEN
# Trade Placed:    NZDUSD     Short    TP:   0.6635707643157877    SL:   0.6589196178421062
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# USDMXN SHORT GREEN
# Trade Placed:    USDMXN     Short    TP:   22.489579732281847    SL:   22.423760133859076
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# USDMXN SHORT GREEN
# Trade Placed:    USDMXN     Short    TP:   22.47057973228185    SL:   22.404760133859078
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.6415575807602303    SL:   1.640121209619885
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.6411975807602301    SL:   1.6397612096198848
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.6409375807602302    SL:   1.6395012096198849
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.64125758076023    SL:   1.6398212096198848
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.6411575807602303    SL:   1.639721209619885
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURAUD SHORT GREEN
# Trade Placed:    EURAUD     Short    TP:   1.6418175807602302    SL:   1.6403812096198849
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURJPY SHORT GREEN
# Trade Placed:    EURJPY     Short    TP:   125.42144177790391    SL:   124.70827911104804
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# ...Analysis Complete
# Analyzing Markets...
# Delta2Y #1 :  1
# Delta2Y #2 :  1
# Delta2Y #3 :  1
# EURJPY SHORT GREEN
# Trade Placed:    EURJPY     Short    TP:   125.40244177790393    SL:   124.68927911104805
# ...Analysis Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-79da5dd61e1b> in <module>
#      19             print("...Analysis Complete")
#      20     t2 = t
# ---> 21     time.sleep(10)
#
# KeyboardInterrupt:
