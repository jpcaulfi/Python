# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sympy import *
init_printing()
import xlrd
from itertools import combinations
from itertools import product
from astropy.table import QTable, Table, Column
from astropy import units as u
from IPython.display import HTML

# %%
df = pd.read_excel('C:/Users/joeca/Desktop/Finance/FOREX/ForexWorkbook.xlsx')

df = df.fillna(0)

ME = (df.iloc[3:, 15] - 1)*-1

PSL = (df.iloc[3:, 16] - 1)*-1

Net = (df.iloc[3:, 18]) * ME * PSL

WL = np.where(Net > 0, 1, -1)

# %%
##
##
## Tier 1 analysis of trades
##
##

# %%
A = df.iloc[3:, 5]
A_Net = sum(A*Net)
A_WL = sum(A*WL)
print("Break & One Retest on 1HR:        ", " Total Net = ", round(A_Net,2), " Wins/Losses = ", A_WL)

B = df.iloc[3:, 6]
B_Net = sum(B*Net)
B_WL = sum(B*WL)
print("Break & Multiple Retests on 1HR:  ", " Total Net = ", round(B_Net,2), " Wins/Losses = ", B_WL)

C = df.iloc[3:, 7]
C_Net = sum(C*Net)
C_WL = sum(C*WL)
print("Break & Single Retest on Daily:   ", " Total Net = ", round(C_Net,2), " Wins/Losses = ", C_WL)

D = df.iloc[3:, 8]
D_Net = sum(D*Net)
D_WL = sum(D*WL)
print("Break & Multiple Retest on Daily: ", " Total Net = ", round(D_Net,2), " Wins/Losses = ", D_WL)

E = df.iloc[3:, 9]
E_Net = sum(E*Net)
E_WL = sum(E*WL)
print("Rising/Falling Peaks:             ", " Total Net = ", round(E_Net,2), " Wins/Losses = ", E_WL)

F = df.iloc[3:, 10]
F_Net = sum(F*Net)
F_WL = sum(F*WL)
print("With Channel Over 1 Month:        ", " Total Net = ", round(F_Net,2), " Wins/Losses = ", F_WL)

G = df.iloc[3:, 11]
G_Net = sum(G*Net)
G_WL = sum(G*WL)
print("With Channel Under 1 Month:       ", " Total Net = ", round(G_Net,2), " Wins/Losses = ", G_WL)

H = df.iloc[3:, 12]
H_Net = sum(H*Net)
H_WL = sum(H*WL)
print("Channel Breakout:                 ", " Total Net = ", round(H_Net,2), " Wins/Losses = ", H_WL)

I = df.iloc[3:, 13]
I_Net = sum(I*Net)
I_WL = sum(I*WL)
print("ICHIMOKU:                 ", " Total Net = ", round(I_Net,2), " Wins/Losses = ", I_WL)

strats = df.iloc[1, 5:14]
y_pos = np.arange(len(strats))
performance = [A_Net,B_Net,C_Net,D_Net,E_Net,F_Net,G_Net,H_Net,I_Net]
perfWL = [A_WL, B_WL, C_WL, D_WL, E_WL, F_WL, G_WL, H_WL, I_WL]

plt.bar(y_pos, performance, align='center', alpha=1)
plt.xticks(y_pos, strats, rotation='vertical')
plt.ylabel('Total Net')
plt.title('Total Net per Strategy')

plt.show()

plt.bar(y_pos, perfWL, align='center', alpha=1)
plt.xticks(y_pos, strats, rotation='vertical')
plt.ylabel('Win/Loss +/-')
plt.title('Wins/Losses per Strategy')

plt.show()
# Out:
# Break & One Retest on 1HR:          Total Net =  169.74  Wins/Losses =  -14
# Break & Multiple Retests on 1HR:    Total Net =  115.34  Wins/Losses =  -5
# Break & Single Retest on Daily:     Total Net =  -25.4  Wins/Losses =  -10
# Break & Multiple Retest on Daily:   Total Net =  -67.43  Wins/Losses =  -7
# Rising/Falling Peaks:               Total Net =  220.23  Wins/Losses =  -11
# With Channel Over 1 Month:          Total Net =  24.14  Wins/Losses =  0
# With Channel Under 1 Month:         Total Net =  -92.3  Wins/Losses =  -11
# Channel Breakout:                   Total Net =  43.36  Wins/Losses =  -5
# ICHIMOKU:                   Total Net =  103.64  Wins/Losses =  2

# %%
##
##
## Tier 2 analysis of trades
##
##

# %%
## 2-VAR COMBINATIONS ##

# %%
Z2 = [A,B,C,D,E,F,G,H,I]

Zcomb2 = list(combinations(Z2, 2))

Zcomb22 = [(x * y) for x, y in Zcomb2]

ZcombNet2 = [x * Net for x in Zcomb22]

ZcombNet22 = [sum(x) for x in ZcombNet2]

Scomb2 = combinations(strats, 2)

r1 = " AND "
Scomb22 = [x + r1 + y for x, y in list(Scomb2)]

y_pos2 = np.arange(len(Scomb22))

plt.bar(y_pos2, ZcombNet22, align='center', alpha=1)
plt.xticks(y_pos2, Scomb2, rotation='vertical')
plt.ylabel('Total Net')
plt.title('Total Net per 2-Strategy Combinations')

plt.show()

# %%
ZcombWL2 = [x * WL for x in Zcomb22]

ZcombWL22 = [sum(x) for x in ZcombWL2]

plt.bar(y_pos2, ZcombWL22, align='center', alpha=1)
plt.xticks(y_pos2, Scomb2, rotation='vertical')
plt.ylabel('Win/Loss +/-')
plt.title('Wins/Losses per 2-Strategy Combinations')

plt.show()

# %%
## 3-VAR COMBINATIONS ##

# %%
Z3 = [A,B,C,D,E,F,G,H,I]

Zcomb3 = list(combinations(Z3, 3))

Zcomb33 = [(x * y * z) for x, y, z in Zcomb3]

ZcombNet3 = [x * Net for x in Zcomb33]

ZcombNet33 = [sum(x) for x in ZcombNet3]

Scomb3 = combinations(strats, 3)

r1 = " AND "
Scomb33 = [x + r1 + y + r1 + z for x, y, z in list(Scomb3)]

y_pos3 = np.arange(len(Scomb33))

plt.bar(y_pos3, ZcombNet33, align='center', alpha=1)
plt.xticks(y_pos3, Scomb3, rotation='vertical')
plt.ylabel('Total Net')
plt.title('Total Net per 3-Strategy Combinations')

plt.show()

# %%
ZcombWL3 = [x * WL for x in Zcomb33]

ZcombWL33 = [sum(x) for x in ZcombWL3]

plt.bar(y_pos3, ZcombWL33, align='center', alpha=1)
plt.xticks(y_pos3, Scomb3, rotation='vertical')
plt.ylabel('Win/Loss +/-')
plt.title('Wins/Losses per 3-Strategy Combinations')

plt.show()

# %%
## 4-VAR COMBINATIONS ##

# %%
Z4 = [A,B,C,D,E,F,G,H,I]

Zcomb4 = list(combinations(Z4, 4))

Zcomb44 = [(w * x * y * z) for w, x, y, z in Zcomb4]

ZcombNet4 = [x * Net for x in Zcomb44]

ZcombNet44 = [sum(x) for x in ZcombNet4]

Scomb4 = combinations(strats, 4)

r1 = " AND "
Scomb44 = [w + r1 + x + r1 + y + r1 + z for w, x, y, z in list(Scomb4)]

y_pos4 = np.arange(len(Scomb44))

plt.bar(y_pos4, ZcombNet44, align='center', alpha=1)
plt.xticks(y_pos4, Scomb4, rotation='vertical')
plt.ylabel('Total Net')
plt.title('Total Net per 4-Strategy Combinations')

plt.show()

# %%
ZcombWL4 = [x * WL for x in Zcomb44]

ZcombWL44 = [sum(x) for x in ZcombWL4]

plt.bar(y_pos4, ZcombWL44, align='center', alpha=1)
plt.xticks(y_pos4, Scomb4, rotation='vertical')
plt.ylabel('Win/Loss +/-')
plt.title('Wins/Losses per 4-Strategy Combinations')

plt.show()

# %%
## 5-VAR COMBINATIONS ##

# %%
Z5 = [A,B,C,D,E,F,G,H,I]

Zcomb5 = list(combinations(Z5, 5))

Zcomb55 = [(v * w * x * y * z) for v, w, x, y, z in Zcomb5]

ZcombNet5 = [x * Net for x in Zcomb55]

ZcombNet55 = [sum(x) for x in ZcombNet5]

Scomb5 = combinations(strats, 5)

r1 = " AND "
Scomb55 = [v + r1 + w + r1 + x + r1 + y + r1 + z for v, w, x, y, z in list(Scomb5)]

y_pos5 = np.arange(len(Scomb55))

plt.bar(y_pos5, ZcombNet55, align='center', alpha=1)
plt.xticks(y_pos5, Scomb5, rotation='vertical')
plt.ylabel('Total Net')
plt.title('Total Net per 5-Strategy Combinations')

plt.show()

# %%
ZcombWL5 = [x * WL for x in Zcomb55]

ZcombWL55 = [sum(x) for x in ZcombWL5]

plt.bar(y_pos5, ZcombWL55, align='center', alpha=1)
plt.xticks(y_pos5, Scomb5, rotation='vertical')
plt.ylabel('Win/Loss +/-')
plt.title('Wins/Losses per 5-Strategy Combinations')

plt.show()

# %%
XS = list(strats) + list(Scomb22) + list(Scomb33) + list(Scomb44) + list(Scomb55)

XN = performance + ZcombNet22 + ZcombNet33 + ZcombNet44 + ZcombNet55
XN = np.around(XN, 2)

XW = perfWL + ZcombWL22 + ZcombWL33 + ZcombWL44 + ZcombWL55

T = list(zip(XS,XN,XW))

table = pd.DataFrame(T, columns=['a','b','c'])
table = table[table['b'] !=0]
table = table[table['c'] !=0]
table = table.sort_values(['b', 'c'], ascending=False)

# %%
table = table.rename(columns={'a': 'Strategy Combination'})
table = table.rename(columns={'b': 'Total Net'})
table = table.rename(columns={'c': 'Win/Loss +/-'})

# %%
HTML(table.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Strategy Combination</th>
#       <th>Total Net</th>
#       <th>Win/Loss +/-</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND With Channel &gt; 1 Month</td>
#       <td>245.87</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks</td>
#       <td>220.23</td>
#       <td>-11</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks</td>
#       <td>197.73</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>169.93</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR</td>
#       <td>169.74</td>
#       <td>-14</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Channel Breakout</td>
#       <td>155.43</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks AND Channel Breakout</td>
#       <td>122.10</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Ichimoku</td>
#       <td>119.30</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR</td>
#       <td>115.34</td>
#       <td>-5</td>
#     </tr>
#     <tr>
#       <td>Ichimoku</td>
#       <td>103.64</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Rising/Falling Peaks AND Channel Breakout</td>
#       <td>83.38</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Channel Breakout</td>
#       <td>77.73</td>
#       <td>-2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>76.70</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Rising/Falling Peaks AND With Channel &gt; 1 Month</td>
#       <td>71.61</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Rising/Falling Peaks AND With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>71.61</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Rising/Falling Peaks</td>
#       <td>67.40</td>
#       <td>-11</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks AND With Channel &gt; 1 Month</td>
#       <td>60.61</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND With Channel &gt; 1 Month</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND With Channel &gt; 1 Month</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND Channel Breakout</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>60.30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks</td>
#       <td>58.54</td>
#       <td>-2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks AND Channel Breakout</td>
#       <td>56.28</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks AND Ichimoku</td>
#       <td>49.21</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Channel Breakout</td>
#       <td>43.36</td>
#       <td>-5</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks AND With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>38.38</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Rising/Falling Peaks AND Channel Breakout</td>
#       <td>28.92</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on Daily AND Ichimoku</td>
#       <td>18.93</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>18.93</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Rising/Falling Peaks AND With Channel &lt; 1 Month</td>
#       <td>14.14</td>
#       <td>-4</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND Ichimoku</td>
#       <td>12.43</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>12.43</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND Channel Breakout</td>
#       <td>9.54</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND Ichimoku</td>
#       <td>6.50</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>6.50</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; 1 Retest With Trend on 1HR AND Break &amp; 1 Retest With Trend on Daily AND With Channel &lt; 1 Month</td>
#       <td>2.85</td>
#       <td>-3</td>
#     </tr>
#     <tr>
#       <td>With Channel &gt; 1 Month AND Channel Breakout</td>
#       <td>-0.36</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Rising/Falling Peaks AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND Rising/Falling Peaks AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Break &amp; Multiple Retests With Trend on Daily AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on 1HR AND Rising/Falling Peaks AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend on Daily AND Rising/Falling Peaks AND With Channel &lt; 1 Month AND Ichimoku</td>
#       <td>-2.27</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <td>Break &amp; Multiple Retests With Trend
